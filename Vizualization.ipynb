# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=[1,2,3,4,5,6]
x2=[10,20,35,67,80,89]
plt.plot(x1,x2)

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
x1=[1,2,3,4,5,6]
x2=[10,20,35,67,80,89]
x3=[2,4,6,8,9,4]
x4=[12,5,6,8,10,20]

plt.plot(x1,x2, linestyle="--", color="red", linewidth=1.5, marker="h", markersize=16,markerfacecolor="b", label="My first line")
plt.plot(x1,x4)
plt.title("This is my first graph in matplotlib")
plt.xlabel("X1")
plt.ylabel("X2")
plt.legend()

# %%
np.linspace(1,2, 5, endpoint=True)
# Out:
# array([1.  , 1.25, 1.5 , 1.75, 2.  ])

# %%
(1+2)/2
# Out:
# 1.5

# %%
(1+1.5)/2
# Out:
# 1.25

# %%
(1.5+2)/2
# Out:
# 1.75

# %%
X=np.linspace(-2*np.pi, 2*np.pi, 2560, endpoint=True)

# %%
s=np.sin(X)
c=np.cos(X)

# %%
plt.plot(X,s, label="sine")
plt.plot(X,c, label="cosine")
plt.legend()

# %%
X=np.linspace(-np.pi, np.pi, 256, endpoint=True)
S=np.sin(X)
C=np.cos(X)

plt.plot(X,S, label="sine")
plt.plot(X,C, label="cosine")
plt.legend()

# %%
X=np.linspace(-np.pi, np.pi, 256, endpoint=True)
S=np.sin(X)
C=np.cos(X)

plt.plot(X,S, label="sine")
plt.plot(X,C, label="cosine")
plt.xlim(-4,4)
plt.xticks([-4,-2,0,2,4])
plt.ylim(-1,1)
plt.yticks([-1,0,1])
plt.legend()

# %%
X=np.linspace(-np.pi, np.pi, 256, endpoint=True)
S=np.sin(X)
C=np.cos(X)

plt.plot(X,S, label="sine")
plt.plot(X,C, label="cosine")
plt.xlim(-4,4)
plt.xticks(np.linspace(-4,4,5,endpoint=True))
plt.ylim(-1,1)
plt.yticks(np.linspace(-1,1,3,endpoint=True))
plt.legend()

# %%
X=np.linspace(-np.pi, np.pi, 256, endpoint=True)
S=np.sin(X)
C=np.cos(X)
plt.plot(X,S, label="sine")
plt.plot(X,C, label="cosine")
plt.xlim(X.min()*1.1,X.max()*1.1)
plt.xticks(np.linspace(X.min()*1.1,X.max()*1.1,5,endpoint=True))
plt.ylim(S.min()*1.1,S.max()*1.1)
plt.yticks(np.linspace(S.min()*1.1,S.max()*1.1,3,endpoint=True))
plt.legend()

# %%
X=np.linspace(-np.pi, np.pi, 256, endpoint=True)
S=np.sin(X)
C=np.cos(X)
plt.plot(X,S, label="sine")
plt.plot(X,C, label="cosine")
plt.xlim(-4,4)
plt.xticks(np.linspace(-4,4,5,endpoint=True))
plt.ylim(-1.5,1.5)
plt.yticks(np.linspace(-1.5,1.5,3,endpoint=True))
plt.legend()

# %%
plt.figure(figsize=(6,5), dpi=100)
X=np.linspace(-np.pi, np.pi, 256, endpoint=True)
S=np.sin(X)
C=np.cos(X)
plt.plot(X,S, label="sine", linewidth=2)
plt.plot(X,C, label="cosine",linewidth=2)
plt.xlim(-4,4)
plt.xticks(np.linspace(-4,4,5,endpoint=True))
plt.ylim(-1.5,1.5)
plt.yticks(np.linspace(-1.5,1.5,3,endpoint=True))
plt.legend(loc="lower left")

# %%
plt.figure(figsize=(6,5), dpi=100)
X=np.linspace(-np.pi, np.pi, 256, endpoint=True)
S=np.sin(X)
C=np.cos(X)
plt.plot(X,S, label="sine", linewidth=2)
plt.plot(X,C, label="cosine",linewidth=2)
plt.plot(X+0.1,S, color="b", alpha=0.25)
plt.xlim(-4,4)
plt.xticks(np.linspace(-4,4,5,endpoint=True))
plt.ylim(-1.5,1.5)
plt.yticks(np.linspace(-1.5,1.5,3,endpoint=True))
plt.legend(loc="lower left")

# %%
plt.figure(figsize=(6,5), dpi=100)
X=np.linspace(-np.pi, np.pi, 256, endpoint=True)
S=np.sin(X)
C=np.cos(X)
plt.plot(X,S, label="sine", linewidth=2)
plt.plot(X,C, label="cosine",linewidth=2)
plt.plot(X+0.1,S, color="b", alpha=0.25)
plt.xlim(X.min()*1.1,X.max()*1.1)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$',r'$-\pi/2$',r'$0$',r'$\pi/2$',r'$\pi$'])
plt.ylim(-1.5,1.5)
plt.yticks(np.linspace(-1.5,1.5,3,endpoint=True))
plt.legend(loc="lower left")

# %%
plt.figure(figsize=(6,5), dpi=100)
X=np.linspace(-np.pi, np.pi, 256, endpoint=True)
S=np.sin(X)
C=np.cos(X)
ax=plt.subplot(111)

ax.spines["right"].set_color('none')
ax.spines["top"].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines["bottom"].set_position(('data','0'))
ax.yaxis.set_ticks_position("left")
ax.spines["left"].set_position(('data','0'))

plt.plot(X,S, label="sine", linewidth=2)
plt.plot(X,C, label="cosine",linewidth=2)
plt.plot(X+0.1,S, color="b", alpha=0.25)
plt.xlim(X.min()*1.1,X.max()*1.1)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$',r'$-\pi/2$',r'$0$',r'$\pi/2$',r'$\pi$'])
plt.ylim(-1.5,1.5)
plt.yticks(np.linspace(-1.5,1.5,3,endpoint=True))
plt.legend(loc="lower left")

# %%
plt.figure(figsize=(6,5), dpi=100)
X=np.linspace(-np.pi, np.pi, 256, endpoint=True)
S=np.sin(X)
C=np.cos(X)
ax=plt.subplot(111)

ax.spines["right"].set_color('none')
ax.spines["top"].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines["bottom"].set_position(('data','0'))
ax.yaxis.set_ticks_position("left")
ax.spines["left"].set_position(('data','0'))

plt.plot(X,S, label="sine", linewidth=2)
plt.plot(X,C, label="cosine",linewidth=2)
plt.plot(X+0.1,S, color="b", alpha=0.25)
plt.xlim(X.min()*1.1,X.max()*1.1)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$',r'$-\pi/2$',r'$0$',r'$\pi/2$',r'$\pi$'])
plt.ylim(-1.5,1.5)

d=2*np.pi/3
plt.plot([d,d], [0,np.sin(d)], color="b", linestyle="--", linewidth=1.5)
plt.scatter(d,np.sin(d), 50,color="r")

plt.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
            xy=(d,np.sin(d)), xycoords="data",
            xytext=(+10,+20), textcoords="offset points", fontsize=15,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3, rad=.2"))

plt.yticks(np.linspace(-1.5,1.5,3,endpoint=True))
plt.legend(loc="lower left")

# %%
x=10
plt.plot([x,x], [x,np.sqrt(10)])

# %%
plt.scatter(d,np.sin(d))

# %% [markdown]
# ## subplots

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
plt.figure()
plt.subplot(1,2,1)
linear_data=np.array([1,3,5,7,9,11])
expo_data=linear_data**2
plt.plot(linear_data,"-o")

# %%
x0=[2,4,7,9]
x1=[10,14,16,10]
x2=[45,67,88,33]
x3=[34,45,66,455]

# %%
plt.subplot(2,2,1)
plt.plot(x0)

plt.subplot(2,2,2)
plt.plot(x1)

plt.subplot(2,2,3)
plt.plot(x2)

plt.subplot(2,2,4)
plt.plot(x3)

plt.show()

# %%
plt.figure()
plt.subplot(1,2,1)
linear_data=np.array([1,3,5,7,9,11])
expo_data=linear_data**2
plt.plot(linear_data,"-o")
plt.subplot(1,2,2)
plt.plot(expo_data, "-o")

# %%
plt.figure()
plt.subplot(2,1,1)
linear_data=np.array([1,3,5,7,9,11])
expo_data=linear_data**2
plt.plot(linear_data,linestyle="-", marker="o") 
plt.subplot(2,1,2)
plt.plot(expo_data, "-h")

# %%
fig, ((ax1,ax2), (ax3,ax4))=plt.subplots(2,2, sharex=True, sharey=True)
ax4.plot(linear_data, "r-o")
ax3.plot(expo_data)

# %% [markdown]
# ## Basic Plots

# %%
year=[2001,2002, 2003,2004, 2005, 2006]
earning_harry=[100,150,470,789,110,800]
earning_Rita=[200,500,700,900,1100,1300]
plt.plot(year, earning_harry, color="g")
plt.plot(year, earning_Rita, color="orange")
plt.xlabel("year")
plt.ylabel("income")
plt.title("Income vs Year")
# Out:
# Text(0.5, 1.0, 'Income vs Year')

# %%
rng=np.random.RandomState(2)
x=rng.randn(400)
y=rng.randn(400)
plt.scatter(x,y, alpha=0.4, cmap="viridis");

# %%
rng=np.random.RandomState(2)
x=rng.randn(100)
y=rng.randn(100)
col=rng.rand(100)
size=1000*rng.rand(100)
plt.scatter(x,y, alpha=0.4, cmap="jet", c=col, s=size)
plt.colorbar();

# %% [markdown]
# ### Bar Plot

# %%
hours=[5,3,8,4,4]
act=["Sleep","Food" ,"Office", "Study", "Others"]

plt.bar(act, hours);

# %%
hours=[5,3,8,4,4]
act=["Sleep","Food" ,"Office", "Study", "Others"]
hours1=[6,2,7,1,8]

col=["r","b","y","c","w"]
plt.bar(act, hours1, label="You")
plt.bar(act, hours,  width=0.5, label="Me")
plt.legend();

# %%
x1=[5,3,8,4,4]
x2=[6,2,7,1,8]
X=np.arange(5)

plt.bar(X,x1, color="b", width=0.40)
plt.bar(X+0.40,x2, color="y", width=0.40)
# Out:
# <BarContainer object of 5 artists>

# %%
print(plt.rcParams["axes.prop_cycle"].by_key()["color"])
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
x1=[5,3,8,4,4]
x2=[6,2,7,1,8]
X=np.arange(5)

plt.bar(X,x1, color="b", width=0.40, label="Me")
plt.bar(X,x2, color="y", width=0.40, bottom=x1,label="Aditya")
plt.legend()

# %% [markdown]
# ### Histogram

# %%
data_hist=[12,4,5,67,12,45,78,122,7,223,677,112,45,2,3,5,8,12,56,89,128,578,23,56,874,450, 480, 340,210]
plt.hist(data_hist);

# %%
data_hist=[12,4,5,67,12,45,78,122,7,223,677,112,45,2,3,5,8,12,56,89,128,578,23,56,874,450, 480, 340,210]
plt.hist(data_hist, bins=6);

# %%
data_hist=[12,4,5,67,12,45,78,122,7,223,677,112,45,2,3,5,8,12,56,89,128,578,23,56,874,450, 480, 340,210]
plt.hist(data_hist, bins=6, rwidth=0.9);

# %%
data_hist=[12,4,5,67,12,45,78,122,7,223,677,112,45,2,3,5,8,12,56,89,128,578,23,56,874,450, 480, 340,210]
binss=[0,20,50, 100, 200, 300,400,500,1000]
plt.hist(data_hist, bins=binss, rwidth=0.9);

# %%
plt.figure(figsize=(6,5))
hours=[5,3,8,4,4]
act=["Sleep","Food" ,"Office", "Study", "Others"]
col=["r","b","y","c","m"]

act2=["Stats", "Prog","LineAlg", "calculus", "Prob", "ML", "DL"]
rank2=[12,17,15,8,9,16,14]
col2=["#c2c2f0", "#ffb3e6","#c2c2f0", "#ffb3e6","#c2c2f0", "#ffb3e6","#c2c2f0" ]

plt.pie(hours,  labels=act,colors=col, startangle=90 , labeldistance=.85)
plt.pie(rank2,  colors=col2, startangle=90, frame=True, radius=0.75, labels=act2, labeldistance=.7, rotatelabels=90)
cent=plt.Circle((0,0), radius=0.5, color="black", fc="white", linewidth=0)
fig=plt.gcf()
fig.gca().add_artist(cent)
plt.axis("equal")
plt.tight_layout()
plt.plot();

# %%
import seaborn as sns
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
import pandas as pd
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")

# %%
df.to_csv("C:\\Users\\Admin\\Desktop\\Training\\PGAA001\\data\\mgp.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("C:\\Users\\Admin\\Desktop\\Training\\PGAA001\\data\\mgp.csv")
# Draw Plot
plt.figure(figsize=(8,7), dpi= 100)
sns.kdeplot(df.loc[df['cyl'] == 4, "cty"], shade=True, color="g", label="Cyl=4", alpha=.7)
sns.kdeplot(df.loc[df['cyl'] == 5, "cty"], shade=True, color="deeppink", label="Cyl=5", alpha=.7)
sns.kdeplot(df.loc[df['cyl'] == 6, "cty"], shade=True, color="dodgerblue", label="Cyl=6", alpha=.7)
sns.kdeplot(df.loc[df['cyl'] == 8, "cty"], shade=True, color="orange", label="Cyl=8", alpha=.7)

# Decoration
plt.title('Density Plot of City Mileage by n_Cylinders', fontsize=22)
plt.legend()
plt.show()

# %%
import joypy 

# Draw Plot
plt.figure(figsize=(16,10), dpi= 80)
fig, axes = joypy.joyplot(df, column=['hwy', 'cty'], by="class", ylim='own', figsize=(14,10))

# Decoration
plt.title('Joy Plot of City and Highway Mileage by Class', fontsize=22)
plt.show()

# %%
# Draw Plot
plt.figure(figsize=(13,10), dpi= 80)
sns.violinplot(x='class', y='hwy', data=df, scale='width', inner='quartile')

# Decoration
plt.title('Violin Plot of Highway Mileage by Vehicle Class', fontsize=22)
plt.show()

# %%
import random

# Import Data

df_raw=pd.read_csv("C:\\Users\\Admin\\Desktop\\Training\\PGAA001\\data\\mgp.csv")
# Prepare Data
df = df_raw.groupby('manufacturer').size().reset_index(name='counts')
n = df['manufacturer'].unique().__len__()+1
all_colors = list(plt.cm.colors.cnames.keys())
random.seed(100)
c = random.choices(all_colors, k=n)

# Plot Bars
plt.figure(figsize=(16,10), dpi= 80)
plt.bar(df['manufacturer'], df['counts'], color=c, width=.5)
for i, val in enumerate(df['counts'].values):
    plt.text(i, val, float(val), horizontalalignment='center', verticalalignment='bottom', fontdict={'fontweight':500, 'size':12})

# Decoration
plt.gca().set_xticklabels(df['manufacturer'], rotation=60, horizontalalignment= 'right')
plt.title("Number of Vehicles by Manaufacturers", fontsize=22)
plt.ylabel('# Vehicles')
plt.ylim(0, 45)
plt.show()

# %%
df = pd.read_csv("C:\\Users\\Admin\\Desktop\\Training\\PGAA001\\data\\mgp.csv")
# Draw Plot
plt.figure(figsize=(13,10), dpi= 80)
sns.distplot(df.loc[df['class'] == 'compact', "cty"], color="dodgerblue", label="Compact", hist_kws={'alpha':.7}, kde_kws={'linewidth':3})
sns.distplot(df.loc[df['class'] == 'suv', "cty"], color="orange", label="SUV", hist_kws={'alpha':.7}, kde_kws={'linewidth':3})
sns.distplot(df.loc[df['class'] == 'minivan', "cty"], color="g", label="minivan", hist_kws={'alpha':.7}, kde_kws={'linewidth':3})
plt.ylim(0, 0.35)

# Decoration
plt.title('Density Plot of City Mileage by Vehicle Type', fontsize=22)
plt.legend()
plt.show()

# %%
df1=pd.read_csv("C:\\Users\\Admin\\Desktop\\Training\\PGAA001\\data\\email.csv")
# Draw Plot
plt.figure(figsize=(13,10), dpi= 80)
group_col = 'Gender'
order_of_bars = df1.Stage.unique()[::-1]
colors = [plt.cm.Spectral(i/float(len(df1[group_col].unique())-1)) for i in range(len(df1[group_col].unique()))]

for c, group in zip(colors, df1[group_col].unique()):
    sns.barplot(x='Users', y='Stage', data=df1.loc[df1[group_col]==group, :], order=order_of_bars, color=c, label=group)

# Decorations    
plt.xlabel("$Users$")
plt.ylabel("Stage of Purchase")
plt.yticks(fontsize=12)
plt.title("Population Pyramid of the Marketing Funnel", fontsize=22)
plt.legend()
plt.show()

# %% [markdown]
# ### Plotting of data with the help of Pandas

# %%
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
df[["displ"]].plot()

# %%
plt.plot(df[["displ"]]);

# %%
df.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
df[["displ", "cyl"]].plot()

# %%
df.plot?

# %%
df.plot.scatter("displ", "cyl")

# %%
df.plot.bar("class", "displ")

# %% [markdown]
# ### Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
np.random.seed(10)
v1=pd.Series(np.random.normal(0,10,1000), name='v1')
v2=pd.Series(2*v1+np.random.normal(65,10,1000), name='v2')

# %%
plt.hist(v1, label="v1")
plt.hist(v2, label="v2")
plt.legend()

# %%
plt.hist([v1,v2], histtype="barstacked")
v3=np.concatenate((v1,v2))
sns.kdeplot(v3)

# %%
sns.distplot(v1)

# %%
sns.distplot(v2)

# %%
sns.pairplot(df)
